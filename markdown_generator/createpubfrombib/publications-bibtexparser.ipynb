# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a TSV of publications with metadata and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)). The core python code is also in `publications.py`. Run either from the `markdown_generator` folder after replacing `publications.tsv` with one containing your data.
#
# TODO: Make this work with BibTex and other databases of citations, rather than Stuart's non-standard TSV format and citation style.

# %% [markdown]
# ## Data format
#
# The TSV needs to have the following columns: pub_date, title, venue, excerpt, citation, site_url, and paper_url, with a header at the top.
#
# - `excerpt` and `paper_url` can be blank, but the others must have values.
# - `pub_date` must be formatted as YYYY-MM-DD.
# - `url_slug` will be the descriptive part of the .md file and the permalink URL for the page about the paper. The .md file will be `YYYY-MM-DD-[url_slug].md` and the permalink will be `https://[yourdomain]/publications/YYYY-MM-DD-[url_slug]`
#
# This is how the raw file looks (it doesn't look pretty, use a spreadsheet or other program to edit and create).

# %% [markdown]
# ## Import pandas
#
# We are using the very handy pandas library for dataframes.

# %%
import bibtexparser

# %% [markdown]
# ## Import TSV
#
# Pandas makes this easy with the read_csv function. We are using a TSV, so we specify the separator as a tab, or `\t`.
#
# I found it important to put this data in a tab-separated values format, because there are a lot of commas in this kind of data and comma-separated values can get messed up. However, you can modify the import statement, as pandas also has read_excel(), read_json(), and others.

# %%
parser = bibtexparser.bparser.BibTexParser(common_strings=True, ignore_nonstandard_types=False)
with open("/Users/leiyu/Dropbox/personalpage/personalpub.bib") as bibtex_file:
    publications = bibtexparser.load(bibtex_file, parser=parser)

publications.entries
# Out:
# [{'doi': '10.1109/MAHSS.2008.4660030',
#   'pages': '328-333',
#   'number': '',
#   'volume': '',
#   'year': '2008',
#   'title': 'SpyMon: Hidden network monitoring for security in wireless sensor Networks',
#   'booktitle': '2008 5th IEEE International Conference on Mobile Ad Hoc and Sensor Systems',
#   'author': 'Lei Yu and Jianzhong Li',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': '4660030'},
#  {'url': 'https://doi.org/10.4236/wsn.2010.29081',
#   'timestamp': 'Sat, 29 Aug 2020 23:20:41 +0200',
#   'doi': '10.4236/wsn.2010.29081',
#   'biburl': 'https://dblp.org/rec/journals/wsn/YuLC10.bib',
#   'bibsource': 'dblp computer science bibliography, https://dblp.org',
#   'volume': '2',
#   'pages': '675--682',
#   'number': '9',
#   'year': '2010',
#   'title': 'Approximate Continuous Aggregation via Time Window Based Compression and Sampling in WSNs',
#   'journal': 'Wirel. Sens. Netw.',
#   'author': 'Lei Yu and Jianzhong Li and Siyao Cheng',
#   'ENTRYTYPE': 'article',
#   'ID': 'DBLP:journals/wsn/YuLC10'},
#  {'doi': '10.3724/SP.J.1001.2009.03488',
#   'volume': '20',
#   'pages': '2705-2720',
#   'month': '11',
#   'year': '2009',
#   'title': 'Distributed Secure Clustering Protocol in Wireless Sensor Networks',
#   'journal': 'Journal of Software',
#   'author': 'Yu, Lei and Li, Jian-Zhong and Luo, Jizhou',
#   'ENTRYTYPE': 'article',
#   'ID': 'article'},
#  {'doi': '10.1109/SAHCN.2009.5168945',
#   'pages': '1-9',
#   'year': '2009',
#   'title': 'Maximize the Lifetime of a Data-gathering Wireless Sensor Network',
#   'booktitle': '2009 6th Annual IEEE Communications Society Conference on Sensor, Mesh and Ad Hoc Communications and Networks',
#   'author': 'Xiong, Shuguang and Li, Jianzhong and Yu, Lei',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': '5168945'},
#  {'pages': '1782-1790',
#   'year': '2009',
#   'title': 'Grouping-Based Resilient Statistical En-Route Filtering for Sensor Networks',
#   'journal': 'IEEE INFOCOM 2009',
#   'author': 'Lei Yu and Jianzhong Li',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2009GroupingBasedRS'},
#  {'year': '2010',
#   'title': 'Bernoulli sampling based ($\\epsilon$, $\\delta$)-approximate aggregation in large-scale sensor networks',
#   'booktitle': 'INFOCOM 2010',
#   'author': 'Siyao Cheng and Jianzhong Li and Qianqian Ren and Lei Yu',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Cheng2010BernoulliSB'},
#  {'pages': '1763-1771',
#   'year': '2011',
#   'title': 'Secure continuous aggregation via sampling-based verification in wireless sensor networks',
#   'journal': '2011 Proceedings IEEE INFOCOM',
#   'author': 'Lei Yu and Jianzhong Li and Siyao Cheng and Shuguang Xiong',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2011SecureCA'},
#  {'volume': '23',
#   'pages': '881-889',
#   'year': '2012',
#   'title': 'Grouping-Enhanced Resilient Probabilistic En-Route Filtering of Injected False Data in WSNs',
#   'journal': 'IEEE Transactions on Parallel and Distributed Systems',
#   'author': 'Jianzhong Li and Lei Yu and Hong Gao and Shuguang Xiong',
#   'ENTRYTYPE': 'article',
#   'ID': 'Li2012GroupingEnhancedRP'},
#  {'pages': '486-494',
#   'year': '2012',
#   'title': 'Location Aware Peak Value Queries in sensor networks',
#   'journal': '2012 Proceedings IEEE INFOCOM',
#   'author': 'Siyao Cheng and Jianzhong Li and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Cheng2012LocationAP'},
#  {'pages': '1008-1016',
#   'year': '2012',
#   'title': 'Efficient algorithms for sensor deployment and routing in sensor networks for network-structured environment monitoring',
#   'journal': '2012 Proceedings IEEE INFOCOM',
#   'author': 'Shuguang Xiong and Lei Yu and Haiying Shen and Chen Wang and Wei Lu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Xiong2012EfficientAF'},
#  {'pages': '162-170',
#   'year': '2012',
#   'title': 'HAS: Hidden anti-theft system based on wireless sensor networks',
#   'journal': '2012 IEEE 31st International Performance Computing and Communications Conference (IPCCC)',
#   'author': 'Longjiang Guo and Jinsheng Duan and Jinbao Li and Lei Yu and Haiying Shen',
#   'ENTRYTYPE': 'article',
#   'ID': 'Guo2012HASHA'},
#  {'pages': '1-10',
#   'year': '2012',
#   'title': 'Cooperative end-to-end traffic redundancy elimination for reducing cloud bandwidth cost',
#   'journal': '2012 20th IEEE International Conference on Network Protocols (ICNP)',
#   'author': 'Lei Yu and Haiying Shen and Karan Sapra and Lin Ye and Zhipeng Cai',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2012CooperativeET'},
#  {'volume': '25',
#   'pages': '1424-1436',
#   'year': '2014',
#   'title': 'Efficient Data Collection for Large-Scale Mobile Monitoring Applications',
#   'journal': 'IEEE Transactions on Parallel and Distributed Systems',
#   'author': 'Haiying Shen and Ze Li and Lei Yu and Chenxi Qiu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Shen2014EfficientDC'},
#  {'volume': '25',
#   'pages': '762-774',
#   'year': '2014',
#   'title': 'Secure Continuous Aggregation in Wireless Sensor Networks',
#   'journal': 'IEEE Transactions on Parallel and Distributed Systems',
#   'author': 'Lei Yu and Jianzhong Li and Siyao Cheng and Shuguang Xiong and Haiying Shen',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2014SecureCA'},
#  {'pages': '455-459',
#   'year': '2013',
#   'title': 'Low-latency multi-flow broadcasts in fading wireless networks',
#   'journal': '2013 Proceedings IEEE INFOCOM',
#   'author': 'Chenxi Qiu and Lei Yu and Haiying Shen and Sohraab Soltani',
#   'ENTRYTYPE': 'article',
#   'ID': 'Qiu2013LowlatencyMB'},
#  {'pages': '1114-1122',
#   'year': '2014',
#   'title': 'Energy-efficient cooperative broadcast in fading wireless networks',
#   'journal': 'IEEE INFOCOM 2014 - IEEE Conference on Computer Communications',
#   'author': 'Chenxi Qiu and Haiying Shen and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Qiu2014EnergyefficientCB'},
#  {'pages': '236-244',
#   'year': '2012',
#   'title': 'MDR: A P2P-based market-guided distributed routing mechanism for high-throughput hybrid wireless networks',
#   'journal': '2012 9th Annual IEEE Communications Society Conference on Sensor, Mesh and Ad Hoc Communications and Networks (SECON)',
#   'author': 'Haiying Shen and Ze Li and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Shen2012MDRAP'},
#  {'pages': '258-267',
#   'year': '2014',
#   'title': 'Bandwidth Guarantee under Demand Uncertainty in Multi-tenant Clouds',
#   'journal': '2014 IEEE 34th International Conference on Distributed Computing Systems',
#   'author': 'Lei Yu and Haiying Shen',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2014BandwidthGU'},
#  {'year': '2015',
#   'title': 'Characterizing data deliverability of greedy routing in wireless sensor networks',
#   'booktitle': 'SECON',
#   'author': 'Jinwei Liu and Lei Yu and Haiying Shen and Yangyang He and Jason O. Hallstrom',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Liu2015CharacterizingDD'},
#  {'pages': '82-90',
#   'year': '2015',
#   'title': 'Congestion-adaptive data collection with accuracy guarantee in cyber-physical systems',
#   'journal': '2015 12th Annual IEEE International Conference on Sensing, Communication, and Networking (SECON)',
#   'author': 'Nematollah Iri and Lei Yu and Haiying Shen and Gregori Caulfield',
#   'ENTRYTYPE': 'article',
#   'ID': 'Iri2015CongestionadaptiveDC'},
#  {'pages': '190-199',
#   'year': '2015',
#   'title': 'Energy-Efficient and Delay-Constrained Broadcast in Time-Varying Energy-Demand Graphs',
#   'journal': '2015 44th International Conference on Parallel Processing',
#   'author': 'Chenxi Qiu and Haiying Shen and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Qiu2015EnergyEfficientAD'},
#  {'volume': '65',
#   'pages': '1802-1815',
#   'year': '2016',
#   'title': 'Low-Latency Multi-Flow Cooperative Broadcast in Fading Wireless Networks',
#   'journal': 'IEEE Transactions on Computers',
#   'author': 'Chenxi Qiu and Haiying Shen and Lei Yu and Sohraab Soltani',
#   'ENTRYTYPE': 'article',
#   'ID': 'Qiu2016LowLatencyMC'},
#  {'volume': '17',
#   'pages': '491-509',
#   'year': '2016',
#   'title': 'A Review of Communication, Driver Characteristics, and Controls Aspects of Cooperative Adaptive Cruise Control (CACC)',
#   'journal': 'IEEE Transactions on Intelligent Transportation Systems',
#   'author': 'Kakan C. Dey and Li Yan and Xujie Wang and Yue Wang and Haiying Shen and Mashrur A. Chowdhury and Lei Yu and Chenxi Qiu and Vivekgautham Soundararaj',
#   'ENTRYTYPE': 'article',
#   'ID': 'Dey2016ARO'},
#  {'volume': '8',
#   'pages': '459-472',
#   'year': '2020',
#   'title': 'Stochastic Load Balancing for Virtual Resource Management in Datacenters',
#   'journal': 'IEEE Transactions on Cloud Computing',
#   'author': 'Lei Yu and Liuhua Chen and Zhipeng Cai and Haiying Shen and Yi Liang and Yi Pan',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2020StochasticLB'},
#  {'pages': '1-9',
#   'year': '2016',
#   'title': 'Dynamic scaling of virtual clusters with bandwidth guarantee in cloud datacenters',
#   'journal': 'IEEE INFOCOM 2016 - The 35th Annual IEEE International Conference on Computer Communications',
#   'author': 'Lei Yu and Zhipeng Cai',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2016DynamicSO'},
#  {'volume': '14',
#   'pages': '915-929',
#   'year': '2021',
#   'title': 'Towards Deadline Guaranteed Cloud Storage Services',
#   'journal': 'IEEE Transactions on Services Computing',
#   'author': 'Guoxin Liu and Haiying Shen and Haoyu Wang and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Liu2021TowardsDG'},
#  {'pages': '212-219',
#   'year': '2016',
#   'title': 'Towards Deadline Guaranteed Cloud Storage Services',
#   'journal': '2016 IEEE 9th International Conference on Cloud Computing (CLOUD)',
#   'author': 'Guoxin Liu and Haiying Shen and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Liu2016TowardsDG'},
#  {'volume': '28',
#   'pages': '446-461',
#   'year': '2017',
#   'title': 'CoRE: Cooperative End-to-End Traffic Redundancy Elimination for Reducing Cloud Bandwidth Cost',
#   'journal': 'IEEE Transactions on Parallel and Distributed Systems',
#   'author': 'Lei Yu and Haiying Shen and Karan Sapra and Lin Ye and Zhipeng Cai',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2017CoRECE'},
#  {'pages': '241-250',
#   'year': '2016',
#   'title': 'Probabilistic Network-Aware Task Placement for MapReduce Scheduling',
#   'journal': '2016 IEEE International Conference on Cluster Computing (CLUSTER)',
#   'author': 'Haiying Shen and Ankur Sarker and Lei Yu and Feng Deng',
#   'ENTRYTYPE': 'article',
#   'ID': 'Shen2016ProbabilisticNT'},
#  {'pages': '1-8',
#   'year': '2016',
#   'title': 'Goodbye to Fixed Bandwidth Reservation: Job Scheduling with Elastic Bandwidth Reservation in Clouds',
#   'journal': '2016 IEEE International Conference on Cloud Computing Technology and Science (CloudCom)',
#   'author': 'Haiying Shen and Lei Yu and Liuhua Chen and Zhuozhao Li',
#   'ENTRYTYPE': 'article',
#   'ID': 'Shen2016GoodbyeTF'},
#  {'volume': '6',
#   'pages': '548-561',
#   'year': '2019',
#   'title': 'Towards Green Wireless Networking: Fading-Resistant Time Constraint Broadcasts Using Cooperative Communication',
#   'journal': 'IEEE Transactions on Network Science and Engineering',
#   'author': 'Chenxi Qiu and Haiying Shen and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Qiu2019TowardsGW'},
#  {'volume': '80',
#   'pages': '139-156',
#   'year': '2018',
#   'title': 'Energy-aware and multi-resource overload probability constraint-based virtual machine dynamic consolidation method',
#   'journal': 'Future Gener. Comput. Syst.',
#   'author': 'Zhihua Li and Chengyu Yan and Lei Yu and Xinrong Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Li2018EnergyawareAM'},
#  {'pages': '50-58',
#   'year': '2017',
#   'title': 'Prediction-based redundant data elimination with content overhearing in wireless networks',
#   'journal': '2017 IEEE International Conference on Pervasive Computing and Communications (PerCom)',
#   'author': 'Haiying Shen and Shenghua He and Lei Yu and Ankur Sarker',
#   'ENTRYTYPE': 'article',
#   'ID': 'Shen2017PredictionbasedRD'},
#  {'volume': '17',
#   'pages': '543-559',
#   'year': '2015',
#   'title': 'Characterizing Data Deliverability of Greedy Routing in Wireless Sensor Networks',
#   'journal': 'IEEE Transactions on Mobile Computing',
#   'author': 'Jinwei Liu and Haiying Shen and Lei Yu and Husnu S. Narman and Jiannan Zhai and Jason O. Hallstrom and Yangyang He',
#   'ENTRYTYPE': 'article',
#   'ID': 'Liu2015CharacterizingDD'},
#  {'pages': '57-64',
#   'year': '2017',
#   'title': 'Privacy-Preserving Inductive Learning with Decision Trees',
#   'journal': '2017 IEEE International Congress on Big Data (BigData Congress)',
#   'author': 'Stacey Truex and Ling Liu and Mehmet Emre Gursoy and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Truex2017PrivacyPreservingIL'},
#  {'year': '2017',
#   'title': 'Dynamic Differential Location Privacy with Personalized Error Bounds',
#   'booktitle': 'NDSS',
#   'author': 'Lei Yu and Ling Liu and Calton Pu',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Yu2017DynamicDL'},
#  {'volume': '29',
#   'pages': '450-465',
#   'year': '2018',
#   'title': 'Towards Bandwidth Guarantee for Virtual Clusters Under Demand Uncertainty in Multi-Tenant Clouds',
#   'journal': 'IEEE Transactions on Parallel and Distributed Systems',
#   'author': 'Lei Yu and Haiying Shen and Zhipeng Cai and Ling Liu and Calton Pu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2018TowardsBG'},
#  {'volume': '6',
#   'pages': '41856-41865',
#   'year': '2018',
#   'title': 'Checking Function-Level Kernel Control Flow Integrity for Cloud Computing',
#   'journal': 'IEEE Access',
#   'author': 'Lin Ye and Xiangzhan Yu and Lei Yu and Bin Guo and Dongyang Zhan and Xiaojiang Du and Mohsen Guizani',
#   'ENTRYTYPE': 'article',
#   'ID': 'Ye2018CheckingFK'},
#  {'volume': '18',
#   'pages': '1068-1082',
#   'year': '2019',
#   'title': 'Data Collection with Accuracy-Aware Congestion Control in Sensor Networks',
#   'journal': 'IEEE Transactions on Mobile Computing',
#   'author': 'Yan Zhuang and Lei Yu and Haiying Shen and William Kolodzey and Nematollah Iri and Gregori Caulfield and Shenghua He',
#   'ENTRYTYPE': 'article',
#   'ID': 'Zhuang2019DataCW'},
#  {'pages': '371-379',
#   'year': '2018',
#   'title': 'Cloud Assisted Traffic Redundancy Elimination for Power Efficiency in Smartphones',
#   'journal': '2018 IEEE 15th International Conference on Mobile Ad Hoc and Sensor Systems (MASS)',
#   'author': 'Shenghua He and Haiying Shen and Vivekgautham Soundararaj and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'He2018CloudAT'},
#  {'volume': '18',
#   'pages': '2315-2329',
#   'year': '2019',
#   'title': 'Differentially Private and Utility Preserving Publication of Trajectory Data',
#   'journal': 'IEEE Transactions on Mobile Computing',
#   'author': 'Mehmet Emre Gursoy and Ling Liu and Stacey Truex and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Gursoy2019DifferentiallyPA'},
#  {'year': '2018',
#   'title': 'Utility-Aware Synthesis of Differentially Private and Attack-Resilient Location Traces',
#   'journal': 'Proceedings of the 2018 ACM SIGSAC Conference on Computer and Communications Security',
#   'author': 'Mehmet Emre Gursoy and Ling Liu and Stacey Truex and Lei Yu and Wenqi Wei',
#   'ENTRYTYPE': 'article',
#   'ID': 'Gursoy2018UtilityAwareSO'},
#  {'pages': '1-1',
#   'year': '2019',
#   'title': 'Demystifying Membership Inference Attacks in Machine Learning as a Service',
#   'journal': 'IEEE Transactions on Services Computing',
#   'author': 'Stacey Truex and Ling Liu and Mehmet Emre Gursoy and Lei Yu and Wenqi Wei',
#   'ENTRYTYPE': 'article',
#   'ID': 'Truex2019DemystifyingMI'},
#  {'pages': '1971-1980',
#   'year': '2019',
#   'title': 'Demystifying Learning Rate Policies for High Accuracy Training of Deep Neural Networks',
#   'journal': '2019 IEEE International Conference on Big Data (Big Data)',
#   'author': 'Yanzhao Wu and Ling Liu and Juhyun Bae and Ka-Ho Chow and Arun Iyengar and Calton Pu and Wenqi Wei and Lei Yu and Qi Zhang',
#   'ENTRYTYPE': 'article',
#   'ID': 'Wu2019DemystifyingLR'},
#  {'pages': '82-91',
#   'year': '2019',
#   'title': 'Effects of Differential Privacy and Data Skewness on Membership Inference Vulnerability',
#   'journal': '2019 First IEEE International Conference on Trust, Privacy and Security in Intelligent Systems and Applications (TPS-ISA)',
#   'author': 'Stacey Truex and Ling Liu and Mehmet Emre Gursoy and Wenqi Wei and Lei Yu',
#   'ENTRYTYPE': 'article',
#   'ID': 'Truex2019EffectsOD'},
#  {'pages': '8-15',
#   'year': '2019',
#   'title': 'GRAHIES: Multi-Scale Graph Representation Learning with Latent Hierarchical Structure',
#   'journal': '2019 IEEE First International Conference on Cognitive Machine Intelligence (CogMI)',
#   'author': 'Lei Yu and Qi Zhang and Donna E. Dillenberger and Ling Liu and Calton Pu and Ka Ho Chow and Mehmet Emre Gursoy and Stacey Truex and Hong Min and Arun Iyengar and Gong Su',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2019GRAHIESMG'},
#  {'pages': '332-349',
#   'year': '2019',
#   'title': 'Differentially Private Model Publishing for Deep Learning',
#   'journal': '2019 IEEE Symposium on Security and Privacy (SP)',
#   'author': 'Lei Yu and Ling Liu and Calton Pu and Mehmet Emre Gursoy and Stacey Truex',
#   'ENTRYTYPE': 'article',
#   'ID': 'Yu2019DifferentiallyPM'},
#  {'year': '2020',
#   'title': 'Towards Byzantine-Resilient Federated Learning via Group-Wise Robust Aggregation',
#   'booktitle': 'Federated Learning',
#   'author': 'Lei Yu and Lingfei Wu',
#   'ENTRYTYPE': 'inproceedings',
#   'ID': 'Yu2020TowardsBF'}]

# %% [markdown]
# ## Escape special characters
#
# YAML is very picky about how it takes a valid string, so we are replacing single and double quotes (and ampersands) with their HTML encoded equivilents. This makes them look not so readable in raw format, but they are parsed and rendered nicely.

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
def parse_author(a):
    """Parses author name in the format of `Last, First Middle` where
    the middle name is sometimes there and sometimes not (and could just be an initial)
    
    Returns: author name as `F. M. Last`
    """
    
    a = a.split(', ')
    last = a[0].strip()
    fm = a[1].split(' ')
    first = fm[0][0] + '.'
    
    if len(fm) > 1:
        middle = fm[1][0] + '.'
    else:
        middle = ''
#     print([first, middle, last])
    
    if not middle == '':
        return first + ' ' + middle + ' ' + last
    else:
        return first + ' ' + last

# for row, item in publications.iterrows():
#     authors = ', '.join([parse_author(a) for a in item['Author'].split('; ')])

# %% [markdown]
# ## Creating the markdown files
#
# This is where the heavy lifting is done. This loops through all the rows in the TSV dataframe, then starts to concatentate a big string (```md```) that contains the markdown for each type. It does the YAML metadata first, then does the description for the individual page.

# %%
p = publications.entries[-1]
p = bibtexparser.customization.add_plaintext_fields(p)
p
# Out:
# {'year': '2020',
#  'title': 'Towards Byzantine-Resilient Federated Learning via Group-Wise Robust Aggregation',
#  'booktitle': 'Federated Learning',
#  'author': 'Lei Yu and Lingfei Wu',
#  'ENTRYTYPE': 'inproceedings',
#  'ID': 'Yu2020TowardsBF',
#  'plain_year': '2020',
#  'plain_title': 'Towards Byzantine-Resilient Federated Learning via Group-Wise Robust Aggregation',
#  'plain_booktitle': 'Federated Learning',
#  'plain_author': 'Lei Yu and Lingfei Wu',
#  'plain_ENTRYTYPE': 'inproceedings',
#  'plain_ID': 'Yu2020TowardsBF'}

# %%
import os


for item in publications.entries:
    
    item = bibtexparser.customization.add_plaintext_fields(item)
    year = item['plain_year'] if 'plain_year' in item else item['plain_date'].split('-')[0]
    key = item['plain_author'].split(',')[0].replace(' ', '').lower() + str(year) + item['plain_title'].split(' ')[0].lower()

    md_filename = key + ".md"
    html_filename = key
    
    ## YAML variables
    
    md = "---\ntitle: \""   + item['plain_title'] + '"\n'
    
    md += """collection: publications"""
    
    md += """\npermalink: /publication/""" + html_filename
    
#     month = month_dict[item['plain_month']] if 'plain_month' in item else 6
#     day = item['plain_day'] if 'plain_day' in item else 15
#     date = datetime.date(int(year), int(month), int(day)).isoformat() + "00:00:00 + 0500"
    if not 'plain_date' in item:
        raise Exception(item)
    date = item['plain_date']
    if len(date) == 4:
        date += "-06-15 00:00:00 +0500"
    elif len(date) == 7:
        date += "-15 00:00:00 +0500"
    elif len(date) == 10:
        date += " 00:00:00 +0500"
    else:
        print(date)
        break
    
    
    md += "\ndate: " + date

    if 'plain_eventtitle' in item:
        venue = item['plain_eventtitle']
    elif 'plain_booktitle' in item:
        venue = item['plain_booktitle']
    elif 'plain_journaltitle' in item:
        venue = item['plain_journaltitle']
    elif 'plain_school' in item:
        venue = item['plain_institution']
    else:
        venue = False
    
    if 'plain_note' in item:
        note = item['plain_note']
        if 'submitted' in note.lower() or 'review' in note.lower() or 'accepted' in note.lower():
            venue += " (<b><i>" + note + "</i></b>)"
        
        
    if venue:
        md += "\nvenue: '" + html_escape(venue) + "'"
    
    if 'plain_url' in item:
        md += "\npaperurl: '" + item['plain_url'] + "'"
    
    if 'plain_doi' in item:
        md += "\ndoi: '" + item['plain_doi'] + "'"
        
    pubtypes = {"inproceedings": "conference",
                "article": "journal",
                "thesis": "academic"}
    md += "\npubtype: '" + pubtypes[item['ENTRYTYPE']] + "'"
    
#     md += "\ncitation: '" + html_escape(item.citation) + "'"
    authors = ', '.join([parse_author(a) for a in item['plain_author'].split(' and ')])
    md += "\nauthors: '" + authors + "'"
    
    md += "\nexcerpt_separator: \"\""
    
    md += "\n---"
    
    ## Markdown description for individual page
        
#     if len(str(item.excerpt)) > 5:
#         md += "\n" + html_escape(item.excerpt) + "\n"
    
    if 'plain_abstract' in item:
        md += "\n" + html_escape(item['plain_abstract']) + "\n"
    
    if 'plain_url' in item:
        md += "\n[Download paper here](" + item['plain_url'] + ")"
    
    if 'plain_doi' in item:
        md += "\n[DOI](" + item['plain_doi'] + ")"
        
#     md += "\nRecommended citation: " + item.citation
    
    md_filename = os.path.basename(md_filename)
       
    with open("../_publications/" + md_filename, 'w') as f:
        f.write(md)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-7-f6a60f7cbc87> in <module>
#      23 #     date = datetime.date(int(year), int(month), int(day)).isoformat() + "00:00:00 + 0500"
#      24     if not 'plain_date' in item:
# ---> 25         raise Exception(item)
#      26     date = item['plain_date']
#      27     if len(date) == 4:
#
# Exception: {'doi': '10.1109/MAHSS.2008.4660030', 'pages': '328-333', 'number': '', 'volume': '', 'year': '2008', 'title': 'SpyMon: Hidden network monitoring for security in wireless sensor Networks', 'booktitle': '2008 5th IEEE International Conference on Mobile Ad Hoc and Sensor Systems', 'author': 'Lei Yu and Jianzhong Li', 'ENTRYTYPE': 'inproceedings', 'ID': '4660030', 'plain_doi': '10.1109/MAHSS.2008.4660030', 'plain_pages': '328-333', 'plain_number': '', 'plain_volume': '', 'plain_year': '2008', 'plain_title': 'SpyMon: Hidden network monitoring for security in wireless sensor Networks', 'plain_booktitle': '2008 5th IEEE International Conference on Mobile Ad Hoc and Sensor Systems', 'plain_author': 'Lei Yu and Jianzhong Li', 'plain_ENTRYTYPE': 'inproceedings', 'plain_ID': '4660030'}

# %% [markdown]
# These files are in the publications directory, one directory below where we're working from.

# %%
# !ls ../_publications/
# Out:
# ls: ../_publications/: No such file or directory

# %%
# !cat ../_publications/behbahani2014aircraft.md
# Out:
# cat: ../_publications/behbahani2014aircraft.md: No such file or directory
